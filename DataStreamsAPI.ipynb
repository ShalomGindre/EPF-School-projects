# %%
#make the requests to get the csv file
import requests

total_deaths_url = "https://covid.ourworldindata.org/data/ecdc/total_deaths.csv"
new_deaths_url = "https://covid.ourworldindata.org/data/ecdc/new_deaths.csv"
csv_file = requests.get(total_deaths_url)
csv_file2 = requests.get(new_deaths_url)
open("total_deaths.csv", "wb").write(csv_file.content)
open("new_deaths.csv", "wb").write(csv_file2.content)

import pandas as pd

csvfname = "total_deaths.csv"
csvfname2 = "new_deaths.csv"
df = pd.read_csv(csvfname, index_col="date", header=0, skipinitialspace=True)
df2 = pd.read_csv(csvfname2, index_col="date", header=0, skipinitialspace=True)

df=df['2020-01-01':'2020-04-22']
df2=df2['2020-03-10':'2020-04-22']
#df.head(100)
#df[:10]
df2[:10]
# Out:
#             World  Afghanistan  Albania  Algeria  Andorra  Angola  Anguilla  \
# date
# 2020-03-10    209          NaN      0.0      NaN      NaN     NaN       NaN
# 2020-03-11    269          0.0      0.0      NaN      NaN     NaN       NaN
# 2020-03-12    326          NaN      1.0      0.0      NaN     NaN       NaN
# 2020-03-13    351          NaN      0.0      1.0      NaN     NaN       NaN
# 2020-03-14    438          NaN      0.0      1.0      0.0     NaN       NaN
# 2020-03-15    354          0.0      0.0      0.0      NaN     NaN       NaN
# 2020-03-16    745          0.0      0.0      2.0      0.0     NaN       NaN
# 2020-03-17    596          0.0      0.0      0.0      0.0     NaN       NaN
# 2020-03-18    789          0.0      0.0      1.0      0.0     NaN       NaN
# 2020-03-19    951          0.0      1.0      1.0      0.0     NaN       NaN
#
#             Antigua and Barbuda  Argentina  Armenia  ...  United States  \
# ...

# %%
print(f"{df.shape} \n" )
print(f"{df.dtypes} \n")
print(f"{df.isna().sum()}")
# Out:
# (113, 207)
#
# World            int64
# Afghanistan    float64
# Albania        float64
# Algeria        float64
# Andorra        float64
#                 ...
# Venezuela      float64
# Vietnam        float64
# Yemen          float64
# Zambia         float64
# Zimbabwe       float64
# Length: 207, dtype: object
#
# World            0
# Afghanistan     10
# Albania         68
# Algeria          5
# Andorra         73
#               ...
# Venezuela       74
# Vietnam          4
# Yemen          100
# Zambia          78
# Zimbabwe        80
# Length: 207, dtype: int64

# %%
#plot some curves of different countries
import matplotlib.pyplot as plt
plt.figure(0)
df['United States'].plot(figsize=(12,7), title ='Total number of deaths for different countries')
df['China'].plot()
df['France'].plot()
df['Italy'].plot()
df['Germany'].plot()
df['Sweden'].plot()
plt.legend()
plt.show()

# %%
df2['Denmark'].plot(figsize=(12,7), title ='New deaths for different countries')
df2['Finland'].plot()
df2['Hungary'].plot()
df2['France'].plot()
df2['Germany'].plot()
df2['Sweden'].plot()
plt.legend()
plt.show()
